# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import seaborn as sns


# se knjizice za machine learning


from sklearn import datasets,metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler



cancer = datasets.load_breast_cancer()

# %%
cancer.feature_names
# Out:
# array(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error',
#        'fractal dimension error', 'worst radius', 'worst texture',
#        'worst perimeter', 'worst area', 'worst smoothness',
#        'worst compactness', 'worst concavity', 'worst concave points',
#        'worst symmetry', 'worst fractal dimension'], dtype='<U23')

# %%
cancer.keys()
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
df = pd.DataFrame(cancer.data, columns=cancer.feature_names)

# %%
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0         17.990         10.38          122.80     1001.0          0.11840
# 1         20.570         17.77          132.90     1326.0          0.08474
# 2         19.690         21.25          130.00     1203.0          0.10960
# 3         11.420         20.38           77.58      386.1          0.14250
# 4         20.290         14.34          135.10     1297.0          0.10030
# 5         12.450         15.70           82.57      477.1          0.12780
# 6         18.250         19.98          119.60     1040.0          0.09463
# 7         13.710         20.83           90.20      577.9          0.11890
# 8         13.000         21.82           87.50      519.8          0.12730
# 9         12.460         24.04           83.97      475.9          0.11860
# 10        16.020         23.24          102.70      797.8          0.08206
# ...

# %%
# probaj vse to standardzirati

# uvoz knjizice

from sklearn.preprocessing import StandardScaler

X = cancer.data
y = cancer.target

scaler = StandardScaler()
x_scaled = scaler.fit_transform(X)

# %%
scaled_df = pd.DataFrame(data=x_scaled,columns=cancer.feature_names)
scaled_df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0     1.097064     -2.073335        1.269934   0.984375         1.568466
# 1     1.829821     -0.353632        1.685955   1.908708        -0.826962
# 2     1.579888      0.456187        1.566503   1.558884         0.942210
# 3    -0.768909      0.253732       -0.592687  -0.764464         3.283553
# 4     1.750297     -1.151816        1.776573   1.826229         0.280372
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0          3.283515        2.652874             2.532475       2.217515
# 1         -0.487072       -0.023846             0.548144       0.001392
# 2          1.052926        1.363478             2.037231       0.939685
# 3          3.402909        1.915897             1.451707       2.867383
# 4          0.539340        1.371011             1.428493      -0.009560
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %%
import seaborn as sns
plt.figure(figsize=(15,15))
sns.heatmap(scaled_df.corr(),annot=True)

# %%
# Zaženimo decision tree classifier

from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor

X1 = scaled_df.values
y1 = cancer.target

# %%
dt = DecisionTreeClassifier(random_state=15, criterion = 'entropy', max_depth = 10)
dt.fit(X1,y1)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=10,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=15, splitter='best')

# %%
# Running Feature Importance

fi_col = []
fi = []

for i,column in enumerate(scaled_df):
    print('The feature importance for {} is : {}'.format(column, dt.feature_importances_[i]))
    
    fi_col.append(column)
    fi.append(dt.feature_importances_[i])
# Out:
# The feature importance for mean radius is : 0.0
# The feature importance for mean texture is : 0.0
# The feature importance for mean perimeter is : 0.006659246512732048
# The feature importance for mean area is : 0.013472884788102829
# The feature importance for mean smoothness is : 0.0
# The feature importance for mean compactness is : 0.0
# The feature importance for mean concavity is : 0.0
# The feature importance for mean concave points is : 0.0
# The feature importance for mean symmetry is : 0.0
# The feature importance for mean fractal dimension is : 0.0
# The feature importance for radius error is : 0.011973493890974156
# The feature importance for texture error is : 0.0
# The feature importance for perimeter error is : 0.0
# The feature importance for area error is : 0.02854518884358611
# The feature importance for smoothness error is : 0.008887934759868758
# The feature importance for compactness error is : 0.0
# The feature importance for concavity error is : 0.0
# ...

# %%
# Creating a Dataframe


fi_df = zip(fi_col, fi)
fi_df = pd.DataFrame(fi_df, columns = ['Feature','Feature Importance'])
fi_df


# Ordering the data
fi_df = fi_df.sort_values('Feature Importance', ascending = False).reset_index()

# Creating columns to keep
columns_to_keep = fi_df['Feature'][0:40]

fi_df
# Out:
#     index                  Feature  Feature Importance
# 0      22          worst perimeter            0.685889
# 1      27     worst concave points            0.100783
# 2      21            worst texture            0.056901
# 3      24         worst smoothness            0.044626
# 4      13               area error            0.028545
# 5      28           worst symmetry            0.024667
# 6       3                mean area            0.013473
# 7      23               worst area            0.012513
# 8      10             radius error            0.011973
# 9      14         smoothness error            0.008888
# 10      2           mean perimeter            0.006659
# 11     19  fractal dimension error            0.005082
# 12     18           symmetry error            0.000000
# 13     25        worst compactness            0.000000
# 14     26          worst concavity            0.000000
# 15     20             worst radius            0.000000
# ...
