# %%
import numpy as np
import pandas as pd

df = pd.read_csv("basicplayerdata-Copy1.csv")

a = df.copy()

# %%
a = a.head()

# %%
a
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   30
# 1           1   20801  Cristiano Ronaldo   32
# 2           2  190871             Neymar   25
# 3           3  176580          L. Suárez   30
# 4           4  167495           M. Neuer   31
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/18/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/18/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/18/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/18/176580.png     Uruguay
# 4  https://cdn.sofifa.org/players/4/18/167495.png     Germany
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/60.png       92         92
# ...

# %%
a["Wage"] =a["Wage"].str.replace("€","")

# %%
a["Wage"] = a["Wage"].str.replace("K", "")
a
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   30
# 1           1   20801  Cristiano Ronaldo   32
# 2           2  190871             Neymar   25
# 3           3  176580          L. Suárez   30
# 4           4  167495           M. Neuer   31
# 5           5  193080             De Gea   26
# 6           6  192985       K. De Bruyne   26
# 7           7  188545     R. Lewandowski   28
# 8           8  183277          E. Hazard   26
# 9           9  182521           T. Kroos   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/18/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/18/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/18/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/18/176580.png     Uruguay
# 4  https://cdn.sofifa.org/players/4/18/167495.png     Germany
# 5  https://cdn.sofifa.org/players/4/18/193080.png       Spain
# ...

# %%
a.sum(axis = 0)
# Out:
# Unnamed: 0                                                    45
# ID                                                       1654178
# Name           L. MessiCristiano RonaldoNeymarL. SuárezM. Neu...
# Age                                                          281
# Photo          https://cdn.sofifa.org/players/4/18/158023.png...
# Nationality    ArgentinaPortugalBrazilUruguayGermanySpainBelg...
# Flag           https://cdn.sofifa.org/flags/52.pnghttps://cdn...
# Overall                                                      918
# Potential                                                    922
# Club           FC BarcelonaReal Madrid CFParis Saint-GermainF...
# Club Logo      https://cdn.sofifa.org/teams/2/18/light/241.pn...
# Value          €118.5M€95.5M€119.5M€97M€61M€74.5M€104.5M€92M€...
# Wage                              565565280510230295395355405340
# Special                                                    20463
# dtype: object

# %%
a["Wage"].()
# Out:
# '565565280510230295395355405340'

# %%
a["Wage"].sum()
# Out:
# '565565280510230295395355405340'

# %%
a["Wage"].dtype()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-295661284ab5> in <module>
# ----> 1 a["Wage"].dtype()
#
# TypeError: 'numpy.dtype' object is not callable

# %%
df.count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-100-0ac66dc6926b> in <module>
# ----> 1 df.count(axis= 0, level= "Nationality")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in count(self, axis, level, numeric_only)
#    7317         if level is not None:
#    7318             return self._count_level(level, axis=axis,
# -> 7319                                      numeric_only=numeric_only)
#    7320
#    7321         if numeric_only:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _count_level(self, level, axis, numeric_only)
#    7351         if not isinstance(count_axis, MultiIndex):
#    7352             raise TypeError("Can only count levels on hierarchical "
# -> 7353                             "{ax}.".format(ax=self._get_axis_name(axis)))
#    7354
#    7355         if frame._is_mixed_type:
#
# ...

# %%
df.groupby(["Nationality"]).count()
# Out:
#                       Unnamed: 0    ID  Name   Age  Photo  Flag  Overall  \
# Nationality
# Afghanistan                    3     3     3     3      3     3        3
# Albania                       38    38    38    38     38    38       38
# Algeria                       61    61    61    61     61    61       61
# Angola                        17    17    17    17     17    17       17
# Antigua & Barbuda              4     4     4     4      4     4        4
# Argentina                    966   966   966   966    966   966      966
# Armenia                       10    10    10    10     10    10       10
# Australia                    230   230   230   230    230   230      230
# Austria                      265   265   265   265    265   265      265
# Azerbaijan                     7     7     7     7      7     7        7
# Barbados                       1     1     1     1      1     1        1
# Belarus                        9     9     9     9      9     9        9
# ...

# %%
z = df.groupby(["Nationality"]).count()
z.sort_values("ID", ascending = False)
# Out:
#                      Unnamed: 0    ID  Name   Age  Photo  Flag  Overall  \
# Nationality
# England                    1647  1647  1647  1647   1647  1647     1647
# Germany                    1163  1163  1163  1163   1163  1163     1163
# Spain                      1039  1039  1039  1039   1039  1039     1039
# France                      982   982   982   982    982   982      982
# Argentina                   966   966   966   966    966   966      966
# Brazil                      802   802   802   802    802   802      802
# Italy                       759   759   759   759    759   759      759
# Colombia                    588   588   588   588    588   588      588
# Japan                       472   472   472   472    472   472      472
# Netherlands                 446   446   446   446    446   446      446
# Republic of Ireland         407   407   407   407    407   407      407
# Sweden                      377   377   377   377    377   377      377
# ...

# %%
df
# Out:
#        Unnamed: 0      ID               Name  Age  \
# 0               0  158023           L. Messi   30
# 1               1   20801  Cristiano Ronaldo   32
# 2               2  190871             Neymar   25
# 3               3  176580          L. Suárez   30
# 4               4  167495           M. Neuer   31
# 5               5  193080             De Gea   26
# 6               6  192985       K. De Bruyne   26
# 7               7  188545     R. Lewandowski   28
# 8               8  183277          E. Hazard   26
# 9               9  182521           T. Kroos   27
# 10             10  178603         M. Hummels   28
# 11             11  167664         G. Higuaín   29
# 12             12  155862       Sergio Ramos   31
# 13             13  211110          P. Dybala   23
# 14             14  200389           J. Oblak   24
# 15             15  192119        T. Courtois   25
# 16             16  177003          L. Modrić   31
# 17             17  168542        David Silva   31
# ...

# %%
#a["Wage"] = a.sum(axis=1)
a
#df['e'] = df.sum(axis=1)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   30
# 1           1   20801  Cristiano Ronaldo   32
# 2           2  190871             Neymar   25
# 3           3  176580          L. Suárez   30
# 4           4  167495           M. Neuer   31
# 5           5  193080             De Gea   26
# 6           6  192985       K. De Bruyne   26
# 7           7  188545     R. Lewandowski   28
# 8           8  183277          E. Hazard   26
# 9           9  182521           T. Kroos   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/18/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/18/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/18/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/18/176580.png     Uruguay
# 4  https://cdn.sofifa.org/players/4/18/167495.png     Germany
# 5  https://cdn.sofifa.org/players/4/18/193080.png       Spain
# ...

# %%
a
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   30
# 1           1   20801  Cristiano Ronaldo   32
# 2           2  190871             Neymar   25
# 3           3  176580          L. Suárez   30
# 4           4  167495           M. Neuer   31
# 5           5  193080             De Gea   26
# 6           6  192985       K. De Bruyne   26
# 7           7  188545     R. Lewandowski   28
# 8           8  183277          E. Hazard   26
# 9           9  182521           T. Kroos   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/18/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/18/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/18/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/18/176580.png     Uruguay
# 4  https://cdn.sofifa.org/players/4/18/167495.png     Germany
# 5  https://cdn.sofifa.org/players/4/18/193080.png       Spain
# ...

# %%
b = a.copy()

# %%
b["Age"]#
# Out:
# 0    30
# 1    32
# 2    25
# 3    30
# 4    31
# 5    26
# 6    26
# 7    28
# 8    26
# 9    27
# Name: Age, dtype: int64

# %%
b["Wage"]
# Out:
# 0    565
# 1    565
# 2    280
# 3    510
# 4    230
# 5    295
# 6    395
# 7    355
# 8    405
# 9    340
# Name: Wage, dtype: object

# %%
b["Wage"] = pd.to_numeric(b["Wage"])

# %%
b["Wage"].sum()
# Out:
# 3940

# %%
df =a.copy()

# %%
df.loc[df["Name"]== "De Gea"]
a
# Out:
#    Unnamed: 0      ID    Name  Age  \
# 5           5  193080  De Gea   26
#
#                                             Photo Nationality  \
# 5  https://cdn.sofifa.org/players/4/18/193080.png       Spain
#
#                                   Flag  Overall  Potential               Club  \
# 5  https://cdn.sofifa.org/flags/45.png       91         93  Manchester United
#
#                                         Club Logo   Value   Wage  Special
# 5  https://cdn.sofifa.org/teams/2/18/light/11.png  €74.5M  €295K     1465

# %%
df.count()
# Out:
# Unnamed: 0     10
# ID             10
# Name           10
# Age            10
# Photo          10
# Nationality    10
# Flag           10
# Overall        10
# Potential      10
# Club           10
# Club Logo      10
# Value          10
# Wage           10
# Special        10
# dtype: int64

# %%
a.count()
# Out:
# Unnamed: 0     10
# ID             10
# Name           10
# Age            10
# Photo          10
# Nationality    10
# Flag           10
# Overall        10
# Potential      10
# Club           10
# Club Logo      10
# Value          10
# Wage           10
# Special        10
# dtype: int64

# %%
a = df.copy()

# %%
a.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage',
#        'Special'],
#       dtype='object')

# %%
b = a.groupby(["Nationality"]).count()["ID"]


#df.groupby(["Nationality"]).count()

# %%
b.sort_values(ascending= False)
b[["Slovenia","Spain"]]
# Out:
# Nationality
# Slovenia      61
# Spain       1039
# Name: ID, dtype: int64

# %%
test = df[["Name","Age","Club","Value"]]

# %%
#test["Value"] = test["Value"].str.replace("€", "")
#test
#test["Value"] = test["Value"].str.replace("M", "")
test["Value"] = test["Value"].str.replace("K", "")
test1 = test
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
#test1["Value"] = pd.to_numeric(test1["Value"])

# %%
test1
# Out:
#                     Name  Age                        Club  Value
# 0               L. Messi   30                FC Barcelona  118.5
# 1      Cristiano Ronaldo   32              Real Madrid CF   95.5
# 2                 Neymar   25         Paris Saint-Germain  119.5
# 3              L. Suárez   30                FC Barcelona     97
# 4               M. Neuer   31            FC Bayern Munich     61
# 5                 De Gea   26           Manchester United   74.5
# 6           K. De Bruyne   26             Manchester City  104.5
# 7         R. Lewandowski   28            FC Bayern Munich     92
# 8              E. Hazard   26                     Chelsea   95.5
# 9               T. Kroos   27              Real Madrid CF     79
# 10            M. Hummels   28            FC Bayern Munich   62.5
# 11            G. Higuaín   29                    Juventus     77
# 12          Sergio Ramos   31              Real Madrid CF     52
# ...

# %%
test1["Value"] = pd.to_numeric(test1["Value"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
test1.dtypes
# Out:
# Name      object
# Age        int64
# Club      object
# Value    float64
# dtype: object

# %%
test1["Value"].sum()
# Out:
# 4765949.2

# %%
test1
# Out:
#                     Name  Age                        Club  Value
# 0               L. Messi   30                FC Barcelona  118.5
# 1      Cristiano Ronaldo   32              Real Madrid CF   95.5
# 2                 Neymar   25         Paris Saint-Germain  119.5
# 3              L. Suárez   30                FC Barcelona   97.0
# 4               M. Neuer   31            FC Bayern Munich   61.0
# 5                 De Gea   26           Manchester United   74.5
# 6           K. De Bruyne   26             Manchester City  104.5
# 7         R. Lewandowski   28            FC Bayern Munich   92.0
# 8              E. Hazard   26                     Chelsea   95.5
# 9               T. Kroos   27              Real Madrid CF   79.0
# 10            M. Hummels   28            FC Bayern Munich   62.5
# 11            G. Higuaín   29                    Juventus   77.0
# 12          Sergio Ramos   31              Real Madrid CF   52.0
# ...

# %%
a
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   30
# 1           1   20801  Cristiano Ronaldo   32
# 2           2  190871             Neymar   25
# 3           3  176580          L. Suárez   30
# 4           4  167495           M. Neuer   31
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/18/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/18/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/18/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/18/176580.png     Uruguay
# 4  https://cdn.sofifa.org/players/4/18/167495.png     Germany
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/60.png       92         92
# ...

# %%
a["Value"] = a["Value"].str.replace("€", "")
a["Value"] = a["Value"].str.replace("M","000000")
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   30
# 1           1   20801  Cristiano Ronaldo   32
# 2           2  190871             Neymar   25
# 3           3  176580          L. Suárez   30
# 4           4  167495           M. Neuer   31
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/18/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/18/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/18/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/18/176580.png     Uruguay
# 4  https://cdn.sofifa.org/players/4/18/167495.png     Germany
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/60.png       92         92
# ...

# %%
aa = df.tail(3)
aa
# Out:
#        Unnamed: 0      ID          Name  Age  \
# 17997       17997  229046      L. Jones   18
# 17998       17998  238813  J. Lundstram   18
# 17999       17999  238306     A. Conway   19
#
#                                                 Photo          Nationality  \
# 17997  https://cdn.sofifa.org/players/4/18/229046.png              England
# 17998  https://cdn.sofifa.org/players/4/18/238813.png              England
# 17999  https://cdn.sofifa.org/players/4/18/238306.png  Republic of Ireland
#
#                                       Flag  Overall  Potential  \
# 17997  https://cdn.sofifa.org/flags/14.png       47         62
# 17998  https://cdn.sofifa.org/flags/14.png       47         65
# 17999  https://cdn.sofifa.org/flags/25.png       47         63
#
#                    Club                                         Club Logo  \
# 17997  Doncaster Rovers   https://cdn.sofifa.org/teams/2/18/light/142.png
# ...

# %%
c = pd.concat([a,aa])
c

c["Value"] = c["Value"].str.replace("€", "")
c["Value"] = c["Value"].str.replace("K", "000")
c["Value"] = c["Value"].str.replace(".","")
cc = c.copy()

# %%
cc
# Out:
#        Unnamed: 0      ID               Name  Age  \
# 0               0  158023           L. Messi   30
# 1               1   20801  Cristiano Ronaldo   32
# 2               2  190871             Neymar   25
# 3               3  176580          L. Suárez   30
# 4               4  167495           M. Neuer   31
# 17997       17997  229046           L. Jones   18
# 17998       17998  238813       J. Lundstram   18
# 17999       17999  238306          A. Conway   19
#
#                                                 Photo          Nationality  \
# 0      https://cdn.sofifa.org/players/4/18/158023.png            Argentina
# 1       https://cdn.sofifa.org/players/4/18/20801.png             Portugal
# 2      https://cdn.sofifa.org/players/4/18/190871.png               Brazil
# 3      https://cdn.sofifa.org/players/4/18/176580.png              Uruguay
# 4      https://cdn.sofifa.org/players/4/18/167495.png              Germany
# ...

# %%
cc["Value"] = pd.to_numeric(cc["Value"])
#cc["Value"]
##test1["Value"] = pd.to_numeric(test1["Value"]) primer

# %%
cc
# Out:
#        Unnamed: 0      ID               Name  Age  \
# 0               0  158023           L. Messi   30
# 1               1   20801  Cristiano Ronaldo   32
# 2               2  190871             Neymar   25
# 3               3  176580          L. Suárez   30
# 4               4  167495           M. Neuer   31
# 17997       17997  229046           L. Jones   18
# 17998       17998  238813       J. Lundstram   18
# 17999       17999  238306          A. Conway   19
#
#                                                 Photo          Nationality  \
# 0      https://cdn.sofifa.org/players/4/18/158023.png            Argentina
# 1       https://cdn.sofifa.org/players/4/18/20801.png             Portugal
# 2      https://cdn.sofifa.org/players/4/18/190871.png               Brazil
# 3      https://cdn.sofifa.org/players/4/18/176580.png              Uruguay
# 4      https://cdn.sofifa.org/players/4/18/167495.png              Germany
# ...

# %%
cc["Value"].sum()/1000000
# Out:
# 3493.17

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage',
#        'Special'],
#       dtype='object')

# %%
#df["Nationality"].count()
# Out:
# 18000

# %%
drzave = df.groupby(["Nationality"]).count()["ID"]

# %%
drzave.sort_values(ascending= False)
# Out:
# Nationality
# England                1647
# Germany                1163
# Spain                  1039
# France                  982
# Argentina               966
# Brazil                  802
# Italy                   759
# Colombia                588
# Japan                   472
# Netherlands             446
# Republic of Ireland     407
# Sweden                  377
# Mexico                  361
# United States           356
# Denmark                 352
# Portugal                340
# Chile                   334
# Korea Republic          327
# Poland                  326
# Norway                  324
# Saudi Arabia            323
# Russia                  301
# Turkey                  298
# Belgium                 285
# Scotland                283
# Austria                 265
# Switzerland             232
# Australia               230
# Uruguay                 150
# Serbia                  134
#                        ...
# Suriname                  2
# ...

# %%
dff = df.copy()
df = dff.copy()

# %%
df.loc[df["Nationality"] == "Germany"]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, ID, Name, Age, Photo, Nationality, Flag, Overall, Potential, Club, Club Logo, Value, Wage, Special]
# Index: []

# %%
df.loc[df["Nationality"]== "Germany"].count()
# Out:
# Unnamed: 0     1163
# ID             1163
# Name           1163
# Age            1163
# Photo          1163
# Nationality    1163
# Flag           1163
# Overall        1163
# Potential      1163
# Club           1163
# Club Logo      1163
# Value          1163
# Wage           1163
# Special        1163
# dtype: int64

# %%
newdf = df.loc[df["Nationality"]== "Germany" #& df(["Club"] == "Barcelona")]
# Out:
#   File "<ipython-input-444-964e7b8e2110>", line 1
#     newdf = df.loc[df["Nationality"]== "Germany"#& df(["Club"] == "Barcelona")]
#                                                                                ^
# SyntaxError: unexpected EOF while parsing

# %%
 new_df = df.loc[(df["Club"]== "FC Barcelona") & (df["Age"] >26)]
#new_df = df.loc[(df["Type 1"]== "Grass") & (df["Type 2"] == "Poison") & (df["HP"] > 70 ) ]

# %%
new_df
# Out:
#       Unnamed: 0      ID             Name  Age  \
# 0              0  158023         L. Messi   30
# 3              3  176580        L. Suárez   30
# 39            39  189511  Sergio Busquets   28
# 40            40  189332       Jordi Alba   28
# 49            49  152729            Piqué   30
# 64            64  168651       I. Rakitić   29
# 175          175  187961         Paulinho   28
# 312          312  199987     J. Cillessen   28
# 1580        1580  202493      Aleix Vidal   27
#
#                                                Photo  Nationality  \
# 0     https://cdn.sofifa.org/players/4/18/158023.png    Argentina
# 3     https://cdn.sofifa.org/players/4/18/176580.png      Uruguay
# 39    https://cdn.sofifa.org/players/4/18/189511.png        Spain
# 40    https://cdn.sofifa.org/players/4/18/189332.png        Spain
# 49    https://cdn.sofifa.org/players/4/18/152729.png        Spain
# 64    https://cdn.sofifa.org/players/4/18/168651.png      Croatia
# ...

# %%
df.loc[df["Club"] == "Paris Saint-Germain"]
df
# Out:
#        Unnamed: 0      ID               Name  Age  \
# 0               0  158023           L. Messi   30
# 1               1   20801  Cristiano Ronaldo   32
# 2               2  190871             Neymar   25
# 3               3  176580          L. Suárez   30
# 4               4  167495           M. Neuer   31
# 5               5  193080             De Gea   26
# 6               6  192985       K. De Bruyne   26
# 7               7  188545     R. Lewandowski   28
# 8               8  183277          E. Hazard   26
# 9               9  182521           T. Kroos   27
# 10             10  178603         M. Hummels   28
# 11             11  167664         G. Higuaín   29
# 12             12  155862       Sergio Ramos   31
# 13             13  211110          P. Dybala   23
# 14             14  200389           J. Oblak   24
# 15             15  192119        T. Courtois   25
# 16             16  177003          L. Modrić   31
# 17             17  168542        David Silva   31
# ...

# %%
zz = df.loc[df["Club"] == "Paris Saint-Germain"]
zz.reset_index(drop = True)
zzz = zz

# %%
zz.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage',
#        'Special'],
#       dtype='object')

# %%
zzz.drop(["Unnamed: 0"],axis = 1,inplace= True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
zzz.reset_index(drop = True)
# Out:
#         ID            Name  Age  \
# 0   190871          Neymar   25
# 1   179813       E. Cavani   30
# 2   199556     M. Verratti   24
# 3   164240    Thiago Silva   32
# 4   231747       K. Mbappé   18
# 5   207865      Marquinhos   23
# 6   202166      J. Draxler   23
# 7   183898     A. Di María   29
# 8   191180      J. Pastore   28
# 9   146530      Dani Alves   34
# 10  210008       A. Rabiot   22
# 11  202371      T. Meunier   25
# 12  225850     P. Kimpembe   21
# 13  193105       A. Areola   24
# 14  188943        K. Trapp   26
# 15  163711       L. Diarra   32
# 16  201510      L. Kurzawa   24
# 17  161648     H. Ben Arfa   30
# 18  183512  Yuri Berchiche   27
# 19  226226     G. Lo Celso   21
# 20  232411       C. Nkunku   19
# 21  229195    L. Callegari   19
# 22  203898       K. Rimane   26
# 23  234795      A. Bernede   18
# 24  242242       S. Cibois   19
# 25  241497        C. Dagba   18
# 26  241495     A. Toufiqui   18
# 27  241496         T. Weah   17
# ...

# %%
zzz.sort_values("Potential",ascending= False)
zzz["Age"].mean()
# Out:
# 23.79310344827586

# %%
df.groupby(["Club"]).count()
# Out:
#                           Unnamed: 0  ID  Name  Age  Photo  Nationality  Flag  \
# Club
#  SSV Jahn Regensburg              26  26    26   26     26           26    26
# 1. FC Heidenheim                  28  28    28   28     28           28    28
# 1. FC Kaiserslautern              30  30    30   30     30           30    30
# 1. FC Köln                        33  33    33   33     33           33    33
# 1. FC Magdeburg                   25  25    25   25     25           25    25
# 1. FC Nürnberg                    29  29    29   29     29           29    29
# 1. FC Union Berlin                27  27    27   27     27           27    27
# 1. FSV Mainz 05                   26  26    26   26     26           26    26
# AC Ajaccio                        26  26    26   26     26           26    26
# AC Horsens                        23  23    23   23     23           23    23
# AD Alcorcón                       30  30    30   30     30           30    30
# ...

# %%
#df.loc[df["Club"] == "Paris Saint-Germain"]

g = df.loc[df["Club"]== "Fc Barcelona"]#.count()
#df.loc[df["Nationality"]== "Germany"].count()
g
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, ID, Name, Age, Photo, Nationality, Flag, Overall, Potential, Club, Club Logo, Value, Wage, Special]
# Index: []

# %%
df
# Out:
#        Unnamed: 0      ID               Name  Age  \
# 0               0  158023           L. Messi   30
# 1               1   20801  Cristiano Ronaldo   32
# 2               2  190871             Neymar   25
# 3               3  176580          L. Suárez   30
# 4               4  167495           M. Neuer   31
# 5               5  193080             De Gea   26
# 6               6  192985       K. De Bruyne   26
# 7               7  188545     R. Lewandowski   28
# 8               8  183277          E. Hazard   26
# 9               9  182521           T. Kroos   27
# 10             10  178603         M. Hummels   28
# 11             11  167664         G. Higuaín   29
# 12             12  155862       Sergio Ramos   31
# 13             13  211110          P. Dybala   23
# 14             14  200389           J. Oblak   24
# 15             15  192119        T. Courtois   25
# 16             16  177003          L. Modrić   31
# 17             17  168542        David Silva   31
# ...

# %%
gg = df.loc[df["Club"]== "FC Barcelona"].count()
gg
# Out:
# Unnamed: 0     21
# ID             21
# Name           21
# Age            21
# Photo          21
# Nationality    21
# Flag           21
# Overall        21
# Potential      21
# Club           21
# Club Logo      21
# Value          21
# Wage           21
# Special        21
# dtype: int64

# %%
df.loc[df["Name"].str.contains("Cristiano",regex = True)]
# Out:
#        Unnamed: 0      ID               Name  Age  \
# 1               1   20801  Cristiano Ronaldo   32
# 2289         2289  207722          Cristiano   30
# 6669         6669  205068          Cristiano   26
# 14336       14336  241361    Cristiano Gomes   22
#
#                                                 Photo Nationality  \
# 1       https://cdn.sofifa.org/players/4/18/20801.png    Portugal
# 2289   https://cdn.sofifa.org/players/4/18/207722.png      Brazil
# 6669   https://cdn.sofifa.org/players/4/18/205068.png    Portugal
# 14336  https://cdn.sofifa.org/players/4/18/241361.png    Portugal
#
#                                       Flag  Overall  Potential  \
# 1      https://cdn.sofifa.org/flags/38.png       94         94
# 2289   https://cdn.sofifa.org/flags/54.png       74         74
# 6669   https://cdn.sofifa.org/flags/38.png       68         70
# 14336  https://cdn.sofifa.org/flags/38.png       61         67
#
# ...

# %%
import re

# %%
df.loc[df["Name"].str.contains("^cr[a-z]*", flags = re.I, regex = True)]
# Out:
#        Unnamed: 0      ID               Name  Age  \
# 1               1   20801  Cristiano Ronaldo   32
# 780           780  200315     Cristian Tello   25
# 2289         2289  207722          Cristiano   30
# 3619         3619  224126            Crislan   25
# 3653         3653  172685             Crespo   30
# 3682         3682  230296   Cristian Lodeira   25
# 4728         4728  219641     Cristian López   28
# 5652         5652  204280   Cristian Herrera   26
# 6669         6669  205068          Cristiano   26
# 7281         7281  230295   Cris Laranjeiros   33
# 7737         7737  195838         Crivellaro   28
# 8950         8950  241179    Cristian Rivero   19
# 9006         9006  205353  Cristian Ceballos   24
# 9374         9374  183160               Cris   33
# 10278       10278  225105    Cristo González   19
# 13222       13222  219730           Cristian   22
# 14336       14336  241361    Cristiano Gomes   22
# 14646       14646  241481      Cristian Sanz   20
#
# ...

# %%
df[loc[df[""]]]
# Out:
#        Unnamed: 0      ID               Name  Age  \
# 0               0  158023           L. Messi   30
# 1               1   20801  Cristiano Ronaldo   32
# 2               2  190871             Neymar   25
# 3               3  176580          L. Suárez   30
# 4               4  167495           M. Neuer   31
# 5               5  193080             De Gea   26
# 6               6  192985       K. De Bruyne   26
# 7               7  188545     R. Lewandowski   28
# 8               8  183277          E. Hazard   26
# 9               9  182521           T. Kroos   27
# 10             10  178603         M. Hummels   28
# 11             11  167664         G. Higuaín   29
# 12             12  155862       Sergio Ramos   31
# 13             13  211110          P. Dybala   23
# 14             14  200389           J. Oblak   24
# 15             15  192119        T. Courtois   25
# 16             16  177003          L. Modrić   31
# 17             17  168542        David Silva   31
# ...

# %%
df
# Out:
#        Unnamed: 0      ID               Name  Age  \
# 0               0  158023           L. Messi   30
# 1               1   20801  Cristiano Ronaldo   32
# 2               2  190871             Neymar   25
# 3               3  176580          L. Suárez   30
# 4               4  167495           M. Neuer   31
# 5               5  193080             De Gea   26
# 6               6  192985       K. De Bruyne   26
# 7               7  188545     R. Lewandowski   28
# 8               8  183277          E. Hazard   26
# 9               9  182521           T. Kroos   27
# 10             10  178603         M. Hummels   28
# 11             11  167664         G. Higuaín   29
# 12             12  155862       Sergio Ramos   31
# 13             13  211110          P. Dybala   23
# 14             14  200389           J. Oblak   24
# 15             15  192119        T. Courtois   25
# 16             16  177003          L. Modrić   31
# 17             17  168542        David Silva   31
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18000 entries, 0 to 17999
# Data columns (total 14 columns):
# Unnamed: 0     18000 non-null int64
# ID             18000 non-null int64
# Name           18000 non-null object
# Age            18000 non-null int64
# Photo          18000 non-null object
# Nationality    18000 non-null object
# Flag           18000 non-null object
# Overall        18000 non-null int64
# Potential      18000 non-null int64
# Club           17751 non-null object
# Club Logo      18000 non-null object
# Value          18000 non-null object
# Wage           18000 non-null object
# Special        18000 non-null int64
# dtypes: int64(6), object(8)
# memory usage: 1.9+ MB

# %%
df["Name"]
# Out:
# 0                 L. Messi
# 1        Cristiano Ronaldo
# 2                   Neymar
# 3                L. Suárez
# 4                 M. Neuer
# 5                   De Gea
# 6             K. De Bruyne
# 7           R. Lewandowski
# 8                E. Hazard
# 9                 T. Kroos
# 10              M. Hummels
# 11              G. Higuaín
# 12            Sergio Ramos
# 13               P. Dybala
# 14                J. Oblak
# 15             T. Courtois
# 16               L. Modrić
# 17             David Silva
# 18               S. Agüero
# 19            G. Chiellini
# 20               G. Buffon
# 21                N. Kanté
# 22                 H. Kane
# 23                P. Pogba
# 24            A. Griezmann
# 25              C. Eriksen
# 26                  Thiago
# 27              A. Sánchez
# 28                D. Godín
# 29               E. Cavani
#                ...
# 17970            D. Rooney
# 17971          T. Miyamoto
# 17972        M. Cerofolini
# ...

# %%
df
# Out:
#        Unnamed: 0      ID               Name  Age  \
# 0               0  158023           L. Messi   30
# 1               1   20801  Cristiano Ronaldo   32
# 2               2  190871             Neymar   25
# 3               3  176580          L. Suárez   30
# 4               4  167495           M. Neuer   31
# 5               5  193080             De Gea   26
# 6               6  192985       K. De Bruyne   26
# 7               7  188545     R. Lewandowski   28
# 8               8  183277          E. Hazard   26
# 9               9  182521           T. Kroos   27
# 10             10  178603         M. Hummels   28
# 11             11  167664         G. Higuaín   29
# 12             12  155862       Sergio Ramos   31
# 13             13  211110          P. Dybala   23
# 14             14  200389           J. Oblak   24
# 15             15  192119        T. Courtois   25
# 16             16  177003          L. Modrić   31
# 17             17  168542        David Silva   31
# ...

# %%
sampler = np.random.permutation(10000)

# %%
sampler
# Out:
# array([5621, 3073, 2465, ..., 4602, 8755, 1114])

# %%
df.take(sampler)
# Out:
#       Unnamed: 0      ID                Name  Age  \
# 5621        5621  201714             D. Böde   30
# 3073        3073  142781        L. Romagnoli   36
# 2465        2465  232381              Wesley   20
# 8600        8600  177099        T. Wachsmuth   30
# 676          676  124375           B. Yılmaz   31
# 5145        5145  199789            M. Yumlu   29
# 4666        4666  167653           M. Troest   30
# 3671        3671  214421       F. Hinestroza   27
# 3530        3530  210016         Diego Lopes   23
# 611          611  190875            J. Kucka   30
# 9404        9404  209027        A. Al Kassar   26
# 8106        8106  210004           B. Saller   24
# 4375        4375  177802         M. Costanzo   29
# 2910        2910  216433         A. El Ghazi   22
# 6996        6996  220502         M. Zaccagni   22
# 4787        4787  206601        M. Sampirisi   24
# 149          149  230666       Gabriel Jesus   20
# 690          690  227950               Yeray   22
# ...

# %%
df.sample(n=20)
# Out:
#        Unnamed: 0      ID             Name  Age  \
# 9705         9705  224715       N. Chernov   21
# 3833         3833  217805  A. Martín Arias   24
# 7342         7342  229027     Gian Martins   24
# 3707         3707  194718          A. Baby   28
# 10324       10324  204637     J. Derstroff   25
# 5268         5268  165520      O. Scarione   31
# 15072       15072  242417         E. Ortiz   20
# 14219       14219  232357       J. Caletti   18
# 3527         3527  199262     Kim Young Uk   26
# 10049       10049  236823    I. Pettersson   20
# 14747       14747  241010         M. Ortíz   23
# 5036         5036  190542    Pedro Sánchez   30
# 6280         6280  205990          H. Reed   22
# 17463       17463  240349        C. Shelis   17
# 11091       11091  232731      R. Hayasaka   31
# 3825         3825  217802   Fábio Sturgeon   23
# 15349       15349  235378       F. Eguelfi   22
# 12404       12404  197998     A. Andersson   26
# ...

# %%
fb = np.random.rand(3,3)
fb
# Out:
# array([[0.0683823 , 0.83841276, 0.63891499],
#        [0.0480079 , 0.37523977, 0.92208922],
#        [0.77508323, 0.40814077, 0.73691006]])

# %%
np.random.permutation(fb)
# Out:
# array([[0.0480079 , 0.37523977, 0.92208922],
#        [0.77508323, 0.40814077, 0.73691006],
#        [0.0683823 , 0.83841276, 0.63891499]])

# %%
df
# Out:
#        Unnamed: 0      ID               Name  Age  \
# 0               0  158023           L. Messi   30
# 1               1   20801  Cristiano Ronaldo   32
# 2               2  190871             Neymar   25
# 3               3  176580          L. Suárez   30
# 4               4  167495           M. Neuer   31
# 5               5  193080             De Gea   26
# 6               6  192985       K. De Bruyne   26
# 7               7  188545     R. Lewandowski   28
# 8               8  183277          E. Hazard   26
# 9               9  182521           T. Kroos   27
# 10             10  178603         M. Hummels   28
# 11             11  167664         G. Higuaín   29
# 12             12  155862       Sergio Ramos   31
# 13             13  211110          P. Dybala   23
# 14             14  200389           J. Oblak   24
# 15             15  192119        T. Courtois   25
# 16             16  177003          L. Modrić   31
# 17             17  168542        David Silva   31
# ...

# %%
 vaja = np.random.permutation(df)

# %%
vaja
# Out:
# array([[10867, 229864, 'Borja Domingo', ..., '€825K', '€3K', 1452],
#        [14660, 242253, 'M. Toye', ..., '€425K', '€1K', 1427],
#        [10949, 228348, 'F. Rherras', ..., '€575K', '€4K', 1809],
#        ...,
#        [9744, 216790, 'C. Grant', ..., '€925K', '€20K', 1812],
#        [912, 111093, 'Reyes', ..., '€6.5M', '€15K', 1892],
#        [1118, 211381, 'S. Boufal', ..., '€11.5M', '€75K', 1819]],
#       dtype=object)

# %%
vaja
# Out:
# array([[10867, 229864, 'Borja Domingo', ..., '€825K', '€3K', 1452],
#        [14660, 242253, 'M. Toye', ..., '€425K', '€1K', 1427],
#        [10949, 228348, 'F. Rherras', ..., '€575K', '€4K', 1809],
#        ...,
#        [9744, 216790, 'C. Grant', ..., '€925K', '€20K', 1812],
#        [912, 111093, 'Reyes', ..., '€6.5M', '€15K', 1892],
#        [1118, 211381, 'S. Boufal', ..., '€11.5M', '€75K', 1819]],
#       dtype=object)

# %%
sampler = np.random.permutation(30)
sampler
# Out:
# array([ 8, 25, 20,  5, 24, 16, 27, 12,  0, 29, 11,  2, 19,  7, 13, 10, 21,
#         6,  9, 28, 18,  1,  3, 15, 14, 17, 26, 22,  4, 23])

# %%
df.take(sampler)
df.sample(n=20)
# Out:
#        Unnamed: 0      ID            Name  Age  \
# 7423         7423  241079     C. Kyriakou   22
# 513           513  148119     I. Akinfeev   31
# 4483         4483  207788  S. Ben Youssef   28
# 8225         8225  160115      E. Manjedo   33
# 318           318  198329         Rodrigo   26
# 15528       15528  228304    K. McFarlane   20
# 13440       13440  211610     J. Anderson   21
# 14952       14952  240837       M. Yandaş   22
# 5630         5630  205555     C. Jorquera   28
# 16119       16119  243234     R. Berişbek   18
# 6491         6491  228829      M. Roberts   26
# 13795       13795  222990      B. Schmidt   21
# 17820       17820  240187     J. Stenmark   18
# 13030       13030  240405     J. González   20
# 6523         6523  198117   A. Bernardini   30
# 10934       10934  225016      G. Di Noia   22
# 4017         4017  185109       M. Sadlok   28
# 5250         5250  231563      F. Mercado   27
# 4167         4167  213829        A. Cerri   21
# ...

# %%
sampler = np.random.permutation(500)
sampler
# Out:
# array([420,  18,  44, 433, 398, 372, 328, 347, 334, 201, 210, 198, 103,
#        449, 404, 251, 370, 315, 457, 116, 443, 373, 305,  82,  96, 270,
#         37, 291, 360, 273, 277, 364, 294, 387, 475, 319, 335,  59, 212,
#        183,  14, 332, 362, 266, 243, 255,   3, 468, 268, 465, 316, 390,
#        142, 399, 127, 173,  19, 162, 163, 480, 414,  73, 185, 450, 211,
#        141, 239, 101, 124, 260, 245,  74, 489, 122, 351, 341, 304, 197,
#          1, 195, 219, 386,   8, 121,  28, 252, 237, 434,  81, 401, 313,
#        271, 460, 238, 207, 230, 293, 115, 411, 228,  57, 379, 405, 336,
#        413, 156, 422,  69, 256, 455, 430, 159, 109, 442, 314, 448,  22,
#        100,  92, 262,  21, 371, 476,  29,  30, 199, 350, 482, 233,  27,
#        419, 483, 395,  86,  40, 128,  91, 281, 221, 415, 339,  72, 113,
#        384, 137,  94, 164, 264, 214, 278, 496,  71, 232, 131, 276, 463,
#         10, 427, 352, 177, 467, 204, 410, 167, 179, 275, 135, 217, 150,
# ...

# %%
df.take(sampler)

# %%
df.take(sampler)
df.sample(n=20)

# %%
preizkus = np.random.permutation(31)
preizkus
# Out:
# array([29,  0, 18, 14, 26, 20, 15, 21, 12, 13, 30, 23, 28,  8,  6,  4, 16,
#        19,  5, 24, 22, 11,  7,  2, 10, 27,  3,  9,  1, 17, 25])

# %%
df.take(preizkus)
df.sample(n = 100)
# Out:
#        Unnamed: 0      ID             Name  Age  \
# 9827         9827  231913       F. Aursnes   21
# 15442       15442  238749          M. Nade   18
# 17004       17004  239075      C. Martínez   18
# 8634         8634  158676         W. Kvist   32
# 7177         7177  223870       N. Aankour   23
# 4417         4417  184471         A. Judge   28
# 17725       17725  234096         B. Hvidt   17
# 10077       10077  221983       M. Sánchez   20
# 7151         7151  222840          R. Coly   21
# 680           680   53914      P. Jagielka   34
# 16427       16427  231682  T. Heward-Belle   20
# 6917         6917  223045        U. Çiftçi   25
# 14426       14426  225519        L. Contin   21
# 16415       16415  221951      J. O'Hanlon   21
# 12668       12668  230834          A. Peña   21
# 9730         9730  204242       M. Barreto   26
# 12993       12993  233484      A. Campbell   18
# 15539       15539  242647        K. Suslov   25
# ...

# %%
sampler = np.random.permutation(500)
sampler

# %%
tt = np.random.permutation(100)
tt
# Out:
# array([30, 81, 69, 40, 61, 76,  3, 34, 77, 92, 19, 23, 35, 52, 29, 79,  5,
#        71, 98, 87, 15, 96, 70, 49, 59, 90, 48, 73,  0,  8, 46, 72, 36, 66,
#        14,  4, 47, 25, 41, 82, 65, 97, 67, 54, 31, 51,  7, 78, 91, 55, 75,
#        68, 57, 88, 26, 27, 13, 95, 42, 99, 44, 18,  1, 11, 94, 20,  2, 60,
#        38, 16,  9, 93, 21, 64, 86, 22, 33, 28, 84, 89, 43, 12, 85, 58, 39,
#        80, 53, 74, 10, 37, 32,  6, 63, 83, 56, 17, 62, 50, 24, 45])

# %%
petrol = np.random.permutation(200)
petrol
# Out:
# array([140,  38,  42,  34,  11,  40, 136, 141,  10, 120,  16, 192,  55,
#        146, 189, 167, 117, 131,  77, 135,  45,  74, 130, 179, 163, 151,
#         17, 194, 132,  29,  28,  82, 182, 199, 155,  64,  19,  72, 142,
#         87, 137,  23, 144,   6, 119,  86, 118, 147, 108,   7, 183, 127,
#         14, 133, 129,  95,   3,  78,  52,   9, 193,  88, 154,   8,  56,
#         39, 152,  73, 159, 102,  33,   0, 121,  31,  22,  75, 143,  65,
#        170, 148,  62, 185,  76,  54, 138, 176, 186, 128,  59, 149, 161,
#         92,  27, 104, 157,  90, 190,  57,  71, 180, 175, 112, 115,  84,
#         96, 197,  89, 113,  30, 110, 184, 172,  44,  81,  61,   2, 188,
#        196,  32,  80,  25, 107,  66, 139,  12,  43, 134, 100, 103, 173,
#         21,  60, 168,  35, 166,  13,  46,   1, 153, 126, 123,  24, 150,
#        177,  20,  49, 145, 156, 125,  48, 109, 165,  70,  93, 106, 164,
#         83,  91,  97,  47,  18, 174, 171,  98,  67,   4, 178, 191, 198,
# ...

# %%
df.take(petrol)
df.sample(n=189)


#df.take(preizkus)
#df.sample(n = 100)
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 680           680   53914         P. Jagielka   34
# 16231       16231  242547         J. Scherzer   21
# 5105         5105  191842         H. Fallatah   31
# 3450         3450  229699        N. Benedetti   20
# 11289       11289  203338           A. Morgan   26
# 3700         3700  179613             B. Sako   29
# 8659         8659  221657         T. Akindele   25
# 3821         3821  198857        S. Romagnoli   27
# 14856       14856  233887           J. Chicco   19
# 15741       15741  219967           D. Hładun   21
# 15397       15397  240523             C. Ezeh   19
# 8794         8794  189942             A. Ligi   27
# 5003         5003  225604             A. Zuev   21
# 126           126  190547             K. Glik   29
# 10922       10922  208885          A. N'Diaye   26
# 2567         2567  222457           B. Mensah   22
# 7570         7570  202459            J. Drost   24
# ...

# %%
test = "Jan je budala"
test
# Out:
# 'Jan je budala'

# %%
import re
test = "Jan je budala"
x = re.findall("[a-c]",test)
print(x)
# Out:
# ['a', 'b', 'a', 'a']

# %%
import re
test = "jan je budala drugic"
x = re.findall("[a-g]",test)
x
# Out:
# ['a', 'e', 'b', 'd', 'a', 'a', 'd', 'g', 'c']

# %%
test2 = "J0an j11e budala pi13cka"
x = re.findall("\d",test2)
x
# Out:
# ['0', '1', '1', '1', '3']

# %%
test = "tukej je nigger 007 jan al pa 123jfdsjk2330'12i3"
x = re.findall("\d",test)
x
# Out:
# ['0', '0', '7', '1', '2', '3', '2', '3', '3', '0', '1', '2', '3']

# %%
arr2 = pd.Series(x)
arr2
# Out:
# 0     0
# 1     0
# 2     7
# 3     1
# 4     2
# 5     3
# 6     2
# 7     3
# 8     3
# 9     0
# 10    1
# 11    2
# 12    3
# dtype: object

# %%
y = arr2[0:5]

# %%
arr22 = pd.DataFrame({"A":["a","b","c","d","e","f"],
                      "B":[y]})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-677-6e83169c13fc> in <module>
#       1 arr22 = pd.DataFrame({"A":["a","b","c","d","e","f"],
# ----> 2                       "B":[y]})
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     390                                  dtype=dtype, copy=copy)
#     391         elif isinstance(data, dict):
# --> 392             mgr = init_dict(data, index, columns, dtype=dtype)
#     393         elif isinstance(data, ma.MaskedArray):
#     394             import numpy.ma.mrecords as mrecords
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     210         arrays = [data[k] for k in keys]
#     211
# ...

# %%
beseda = "urban hoce 2 milijona"
x = re.findall("\d",beseda)
x
# Out:
# ['2']

# %%
y = re.split("\s",beseda)
y
# Out:
# ['urban', 'hoce', '2', 'milijona']

# %%
ares = np.array(y)
ares
# Out:
# array(['urban', 'hoce', '2', 'milijona'], dtype='<U8')

# %%
import pandas as pd
data = {'Name':["a","b","c","d"],'Age':(ares)}
df = pd.DataFrame(data)
df
# Out:
#   Name       Age
# 0    a     urban
# 1    b      hoce
# 2    c         2
# 3    d  milijona

# %%
data1 = {"Ime":["a","b","c","d"],"starost":[1,2,3,4]}
dff = pd.DataFrame(data1)
dff
# Out:
#   Ime  starost
# 0   a        1
# 1   b        2
# 2   c        3
# 3   d        4

# %%
data2 = {"Ime":["a","b","c","d"],"vnos":(ares)}
data3 = pd.DataFrame(data2)
data3
# Out:
#   Ime      vnos
# 0   a     urban
# 1   b      hoce
# 2   c         2
# 3   d  milijona

# %%
import pandas as pd
data = {'Name':["a","b","c","d"],'Age':(ares)}
df = pd.DataFrame(data)
df

# %%
text = "Hasbro, ki ima na leto več kot pet milijard dolarjev prometa, je lastnik več sto blagovnih znamk znanih igrač in je največji proizvajalec namiznih iger na svetu. Med drugim je tudi lastnik znane blagovne znamke Monopoly. "

# %%
z = "to je slab dan"
za = re.split("\s",z)
za
# Out:
# ['to', 'je', 'slab', 'dan']

# %%
df
# Out:
#   Name       Age
# 0    a     urban
# 1    b      hoce
# 2    c         2
# 3    d  milijona

# %%
#nova fifa

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("fifa_data.csv")
df
dff= df

# %%
dff
# Out:
#        Unnamed: 0      ID                  Name  Age  \
# 0               0  158023              L. Messi   31
# 1               1   20801     Cristiano Ronaldo   33
# 2               2  190871             Neymar Jr   26
# 3               3  193080                De Gea   27
# 4               4  192985          K. De Bruyne   27
# 5               5  183277             E. Hazard   27
# 6               6  177003             L. Modrić   32
# 7               7  176580             L. Suárez   31
# 8               8  155862          Sergio Ramos   32
# 9               9  200389              J. Oblak   25
# 10             10  188545        R. Lewandowski   29
# 11             11  182521              T. Kroos   28
# 12             12  182493              D. Godín   32
# 13             13  168542           David Silva   32
# 14             14  215914              N. Kanté   27
# 15             15  211110             P. Dybala   24
# 16             16  202126               H. Kane   24
# ...

# %%
dffa = np.random.permutation(50)
dffa
# Out:
# array([ 1, 46, 36, 48,  7, 30, 41, 31, 23,  6, 24, 25, 40, 43, 19,  5, 49,
#         3, 44, 42, 11, 27, 29,  0, 38, 12, 15, 45,  9, 16, 22, 20, 21, 37,
#        26, 47, 10,  8,  2, 13, 18, 17, 34, 14, 33,  4, 39, 35, 32, 28])

# %%
dff = dff.take(dffa)

# %%
dff
# Out:
#     Unnamed: 0      ID               Name  Age  \
# 1            1   20801  Cristiano Ronaldo   33
# 46          46  193041           K. Navas   31
# 36          36  173731            G. Bale   28
# 48          48  192387        C. Immobile   28
# 7            7  176580          L. Suárez   31
# 30          30  197781               Isco   26
# 41          41    1179          G. Buffon   40
# 31          31  190460         C. Eriksen   26
# 23          23  153079          S. Agüero   30
# 6            6  177003          L. Modrić   32
# 24          24  138956       G. Chiellini   33
# 25          25  231747          K. Mbappé   19
# 40          40  162835      S. Handanovič   33
# 43          43  201399          M. Icardi   25
# 19          19  192119        T. Courtois   26
# 5            5  183277          E. Hazard   27
# 49          49  189332         Jordi Alba   29
# 3            3  193080             De Gea   27
# 44          44  201024       K. Koulibaly   27
# ...

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 1 to 28
# Data columns (total 89 columns):
# Unnamed: 0                  50 non-null int64
# ID                          50 non-null int64
# Name                        50 non-null object
# Age                         50 non-null int64
# Photo                       50 non-null object
# Nationality                 50 non-null object
# Flag                        50 non-null object
# Overall                     50 non-null int64
# Potential                   50 non-null int64
# Club                        50 non-null object
# Club Logo                   50 non-null object
# Value                       50 non-null object
# Wage                        50 non-null object
# Special                     50 non-null int64
# Preferred Foot              50 non-null object
# International Reputation    50 non-null float64
# Weak Foot                   50 non-null float64
# Skill Moves                 50 non-null float64
# ...

# %%
#dff.columns[20:40]
#dff.drop([20,40])
dff.drop(dff.iloc[:,20:40],inplace= True, axis=1)

# %%
a = dff

# %%
a.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type'],
#       dtype='object')

# %%
len(a.columns)
# Out:
# 20

# %%
dff.drop(columns= ["Photo"],inplace= True)
#dff.drop(columns= ["Flag"],inplace= True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
dff.drop(columns=["Club Logo"],inplace= True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
a = dff.copy()

# %%
dff.drop(columns=["Unnamed: 0"],inplace= True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
dff.reset_index(inplace=True)
dff.drop(["level_0","index"],axis = 1)
dff
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-813-aab245f29966> in <module>
# ----> 1 dff.reset_index(inplace=True)
#       2 dff.drop(["level_0","index"],axis = 1)
#       3 dff
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4429                 # to ndarray and maybe infer different dtype
#    4430                 level_values = _maybe_casted_values(lev, lab)
# -> 4431                 new_obj.insert(0, name, level_values)
#    4432
#    4433         new_obj.index = new_index
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3471         value = self._sanitize_column(column, value, broadcast=False)
#    3472         self._data.insert(loc, column, value,
# ...

# %%
dff.drop(columns=["index"],inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
dff.drop(columns=["level_0"],inplace = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
a= dff.copy()

# %%
#a.loc[a["Club"]== "FC Barcelona"]
a.loc[a["Club"]== "FC Bayern München"]
# Out:
#         ID            Name  Age Nationality  Overall  Potential  \
# 30  167495        M. Neuer   32     Germany       89         89
# 36  188545  R. Lewandowski   29      Poland       90         90
# 42  178603      M. Hummels   29     Germany       88         88
# 49  198710    J. Rodríguez   26    Colombia       88         89
#
#                  Club   Value   Wage  Special Preferred Foot  \
# 30  FC Bayern München    €38M  €130K     1473          Right
# 36  FC Bayern München    €77M  €205K     2152          Right
# 42  FC Bayern München    €46M  €160K     2038          Right
# 49  FC Bayern München  €69.5M  €315K     2171           Left
#
#     International Reputation  Weak Foot  Skill Moves       Work Rate Body Type
# 30                       5.0        4.0          1.0  Medium/ Medium    Normal
# 36                       4.0        4.0          4.0    High/ Medium    Normal
# 42                       4.0        3.0          3.0    High/ Medium    Normal
# ...

# %%
aa =a.loc[(a["Preferred Foot"]== "Left") & (a["Potential"]>90)]#.count()[0]
aa
# Out:
#         ID       Name  Age Nationality  Overall  Potential          Club  \
# 19  205600  S. Umtiti   24      France       87         92  FC Barcelona
# 23  158023   L. Messi   31   Argentina       94         94  FC Barcelona
# 26  211110  P. Dybala   24   Argentina       89         94      Juventus
#
#       Value   Wage  Special Preferred Foot  International Reputation  \
# 19     €57M  €205K     2147           Left                       3.0
# 23  €110.5M  €565K     2202           Left                       5.0
# 26     €89M  €205K     2092           Left                       3.0
#
#     Weak Foot  Skill Moves       Work Rate Body Type
# 19        3.0          2.0    Medium/ High    Normal
# 23        4.0          4.0  Medium/ Medium     Messi
# 26        3.0          4.0    High/ Medium    Normal

# %%
a.loc[a["Preferred Foot"]== "Right"].count()[0]
# Out:
# 36

# %%
a.loc[a["Potential"]>90]
# Out:
#         ID               Name  Age Nationality  Overall  Potential  \
# 0    20801  Cristiano Ronaldo   33    Portugal       94         94
# 4   176580          L. Suárez   31     Uruguay       91         91
# 5   197781               Isco   26       Spain       88         91
# 7   190460         C. Eriksen   26     Denmark       88         91
# 9   177003          L. Modrić   32     Croatia       91         91
# 11  231747          K. Mbappé   19      France       88         95
# 15  183277          E. Hazard   27     Belgium       91         91
# 17  193080             De Gea   27       Spain       91         93
# 19  205600          S. Umtiti   24      France       87         92
# 23  158023           L. Messi   31   Argentina       94         94
# 26  211110          P. Dybala   24   Argentina       89         94
# 27  195864           P. Pogba   25      France       87         91
# 28  200389           J. Oblak   25    Slovenia       90         93
# ...

# %%
aa
# Out:
#         ID       Name  Age Nationality  Overall  Potential          Club  \
# 19  205600  S. Umtiti   24      France       87         92  FC Barcelona
# 23  158023   L. Messi   31   Argentina       94         94  FC Barcelona
# 26  211110  P. Dybala   24   Argentina       89         94      Juventus
#
#       Value   Wage  Special Preferred Foot  International Reputation  \
# 19     €57M  €205K     2147           Left                       3.0
# 23  €110.5M  €565K     2202           Left                       5.0
# 26     €89M  €205K     2092           Left                       3.0
#
#     Weak Foot  Skill Moves       Work Rate Body Type
# 19        3.0          2.0    Medium/ High    Normal
# 23        4.0          4.0  Medium/ Medium     Messi
# 26        3.0          4.0    High/ Medium    Normal

# %%
ca = df.groupby("Nationality").count()["ID"].copy()
#c.sort_values("ID",ascending = False)
ca.sort_values(ascending = False,inplace = True)

# %%
#ca = pd.DataFrame(ca)
#g = ""
#ca["Total"] = g
#ca["Nationality"]
ca
#ca.reindex(ca,method = "ffill")
# Out:
#                         ID Total
# Nationality
# England               1662
# Germany               1198
# Spain                 1072
# Argentina              937
# France                 914
# Brazil                 827
# Italy                  702
# Colombia               618
# Japan                  478
# Netherlands            453
# Sweden                 397
# China PR               392
# Chile                  391
# Republic of Ireland    368
# Mexico                 366
# United States          353
# Poland                 350
# Norway                 341
# Saudi Arabia           340
# Denmark                336
# Korea Republic         335
# Portugal               322
# Turkey                 303
# Austria                298
# Scotland               286
# Belgium                260
# Australia              236
# Switzerland            220
# Uruguay                149
# Senegal                130
# ...                    ...   ...
# Uzbekistan               2
# ...

# %%
aa
# Out:
#         ID       Name  Age Nationality  Overall  Potential          Club  \
# 19  205600  S. Umtiti   24      France       87         92  FC Barcelona
# 23  158023   L. Messi   31   Argentina       94         94  FC Barcelona
# 26  211110  P. Dybala   24   Argentina       89         94      Juventus
#
#       Value   Wage  Special Preferred Foot  International Reputation  \
# 19     €57M  €205K     2147           Left                       3.0
# 23  €110.5M  €565K     2202           Left                       5.0
# 26     €89M  €205K     2092           Left                       3.0
#
#     Weak Foot  Skill Moves       Work Rate Body Type
# 19        3.0          2.0    Medium/ High    Normal
# 23        4.0          4.0  Medium/ Medium     Messi
# 26        3.0          4.0    High/ Medium    Normal

# %%
#import matplotlib.pltyplot as plt
import matplotlib.pyplot as plt

# %%
plt.hist(aa.Potential)
plt.show()

# %%
plt.hist(df.Potential)
plt.show()

# %%
#bins = [30,32]

plt.hist(df.Age,color = "red")#,bins=bins)
plt.show()

# %%
juventus = df.loc[df["Club"]== "Juventus"]["Overall"]
bayern = df.loc[df["Club"]== "FC Bayern München"]["Overall"]#,"Age","Value","Name"]]
#juventus
#bayern


labels = ["FC Juventus", "FC Bayern Munchen"]

plt.figure(figsize=(5,8))

plt.title("graf")
plt.ylabel("y label")
plt.xlabel("x label")
plt.boxplot([juventus,bayern],labels = labels)
plt.show()

# %%
#df.loc[df["Club"]== "FC Bayern München"]#["Overall"]

# %%
#df

# %%
dgraphPolar(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1016-9f4fb9be0ade> in <module>
# ----> 1 graphPolar(0)
#
# NameError: name 'graphPolar' is not defined

# %%
import seaborn as sns
plt.style.use('whitegrid')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\style\core.py in use(style)
#     110             try:
# --> 111                 rc = rc_params_from_file(style, use_default_template=False)
#     112                 _apply_style(rc)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in rc_params_from_file(fname, fail_on_error, use_default_template)
#     974     """
# --> 975     config_from_file = _rc_params_in_file(fname, fail_on_error)
#     976
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in _rc_params_in_file(fname, fail_on_error)
#     903     rc_temp = {}
# --> 904     with _open_file_or_url(fname) as fd:
#     905         try:
#
# C:\ProgramData\Anaconda3\lib\contextlib.py in __enter__(self)
#     111         try:
# --> 112             return next(self.gen)
# ...

# %%
plt.figure(figsize = (10, 5))
plt.style.use('whitegrid')
ax = sns.countplot('Overall', data = df, palette = 'bone')
ax.set_xlabel(xlabel = 'Different Positions in Football', fontsize = 16)
ax.set_ylabel(ylabel = 'Count of Players', fontsize = 16)
ax.set_title(label = 'Comparison of Positions and Players', fontsize = 20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\style\core.py in use(style)
#     110             try:
# --> 111                 rc = rc_params_from_file(style, use_default_template=False)
#     112                 _apply_style(rc)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in rc_params_from_file(fname, fail_on_error, use_default_template)
#     974     """
# --> 975     config_from_file = _rc_params_in_file(fname, fail_on_error)
#     976
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in _rc_params_in_file(fname, fail_on_error)
#     903     rc_temp = {}
# --> 904     with _open_file_or_url(fname) as fd:
#     905         try:
#
# C:\ProgramData\Anaconda3\lib\contextlib.py in __enter__(self)
#     111         try:
# --> 112             return next(self.gen)
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
df["Name"].count()
# Out:
# 18207

# %%
#df.iloc[df.groupby(df["Position"])["Potential"].idxmax()][["Position","Name","Age","Club","Potential"]]
a= df.iloc[df.groupby(["Potential"]).idxmax()][["Position","Name","Age","Club","Potential"]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1050-aa97aaf52f62> in <module>
#       1 #df.iloc[df.groupby(df["Position"])["Potential"].idxmax()][["Position","Name","Age","Club","Potential"]]
# ----> 2 a= df.iloc[df.groupby(["Potential"]).idxmax()][["Position","Name","Age","Club","Potential"]]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2219         # a list of integers
#    2220         elif is_list_like_indexer(key):
# -> 2221             return self._get_list_axis(key, axis=axis)
# ...

# %%
df.loc[df["Club"] == "FC Bayern München"]
# Out:
#        Unnamed: 0      ID              Name  Age  \
# 10             10  188545    R. Lewandowski   29
# 22             22  167495          M. Neuer   32
# 28             28  198710      J. Rodríguez   26
# 34             34  178603        M. Hummels   29
# 66             66  189596         T. Müller   28
# 67             67  189509            Thiago   27
# 82             82  212622        J. Kimmich   23
# 85             85  197445          D. Alaba   26
# 95             95  183907        J. Boateng   29
# 115           115  212190           N. Süle   22
# 154           154    9014         A. Robben   34
# 162           162  219683        C. Tolisso   23
# 164           164  213345          K. Coman   22
# 169           169  209658       L. Goretzka   23
# 179           179  206113         S. Gnabry   22
# 215           215  177610     Javi Martínez   29
# 221           221  156616         F. Ribéry   35
# 509           509  186569        S. Ulreich   29
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                      0
# ID                              0
# Name                            0
# Age                             0
# Photo                           0
# Nationality                     0
# Flag                            0
# Overall                         0
# Potential                       0
# Club                          241
# Club Logo                       0
# Value                           0
# Wage                            0
# Special                         0
# Preferred Foot                 48
# International Reputation       48
# Weak Foot                      48
# Skill Moves                    48
# Work Rate                      48
# Body Type                      48
# Real Face                      48
# Position                       60
# Jersey Number                  60
# Joined                       1553
# Loaned From                 16943
# Contract Valid Until          289
# Height                         48
# ...
